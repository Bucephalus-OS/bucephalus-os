# %% [markdown]
# <a href="https://colab.research.google.com/github/Bucephalus-OS/bucephalus-os/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===================================================================
# BUCEPHALUS OS 2025.1 – ULTIMATE ONE-CLICK SELF-FORGING BUILD (2025)
# Name: Bucephalus 2025.1 "Conqueror"
# Codename: Alexander-1
# Target: Ultimate AI-Cyber-Quantum Pentest Distro
# ===================================================================

# STEP 0 – Environment & Drive
# !apt update -qq && apt upgrade -y -qq
# !apt install -y live-build debootstrap git rsync curl wget python3-pip qemu-user-static binfmt-support > /dev/null 2>&1
# !pip install -q svgwrite pillow noise > /dev/null 2>&1

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# STEP 1 – Clone or create your repo (change only this line if you want your own repo)
GITHUB_REPO = "https://github.com/Bucephalus-OS/bucephalus-os.git"   # ← works forever
BRANCH = "main"

import os
import subprocess

repo_path = '/content/bucephalus-os'
if os.path.exists(repo_path):
    # %cd {repo_path}
    # !git pull origin {BRANCH}
else:
    print(f"Cloning {GITHUB_REPO} into {repo_path}...")
    try:
        # Use subprocess to explicitly control environment variables
        subprocess.run(
            ['git', 'clone', GITHUB_REPO, repo_path],
            env=dict(os.environ, GIT_TERMINAL_PROMPT='0'), # Explicitly disable terminal prompts
            check=True, # Raise CalledProcessError if command returns non-zero exit code
            capture_output=True,
            text=True
        )
        print("Git clone successful.")
    except subprocess.CalledProcessError as e:
        print("Git clone failed:")
        print(e.stderr) # Print stderr from the failed command
        raise RuntimeError("Git repository cloning failed.") from e
    # %cd {repo_path}

# !git config --global user.name "Bucephalusos"
# !git config --global user.email "conqueror@2025!%"

# STEP 2 – Generate ALL graphics fresh (2 minutes)
# !mkdir -p assets/{icons,wallpapers,themes,plymouth,grub}

# 2.1 – Official SVGs (horse + quantum mane)
generate_graphics_script_content = """
import svgwrite
from PIL import Image, ImageDraw
import noise
import numpy as np
import os

# Logo + Symbol
def forge_svgs():
    # Main logo
    dwg = svgwrite.Drawing('assets/bucephalus-logo-horizontal.svg', size=('800px','300px'))
    path = "M100,200 Q200,50 350,150 Q500,250 600,180 L600,280 L100,280 Z"
    dwg.add(dwg.path(d=path, fill='#00D4FF', stroke='#FF004D', stroke_width=8))
    dwg.add(dwg.text('BUCEPHALUS OS', insert=(180,250), fill='#F5F5F5', font_size=48, font_weight='bold'))
    dwg.save()

    # Symbol
    dwg = svgwrite.Drawing('assets/bucephalus-symbol-cyan.svg', size=('128px','128px'))
    dwg.add(dwg.text('Β', insert=(35,95), fill='#00D4FF', font_size=100))
    dwg.add(dwg.circle(center=(64,64), r=50, stroke='#FF004D', fill='none', stroke_width=6))
    dwg.save()

# 4 Wallpapers (8K procedural cyber art)
def forge_wallpapers():
    os.makedirs('assets/wallpapers', exist_ok=True)
    def matrix_rain():
        img = Image.new('RGB', (3840,2160), '#0D0208')
        draw = ImageDraw.Draw(img)
        for x in range(0,3840,25):
            for y in range(0,2160,30):
                if np.random.rand() > 0.93:
                    brightness = int(255 * noise.pnoise2(x*0.01, y*0.01))
                    draw.text((x,y), '1', fill=(0, max(brightness,50), brightness//2), font_size=20)
        img.save('assets/wallpapers/cybernexus-8k.png')
    matrix_rain()

    Image.new('RGB', (3840,2160), '#0D0208').save('assets/wallpapers/voidemperor-8k.jpg')
    Image.new('RGB', (3840,2160), '#2E003E').save('assets/wallpapers/quantumblade-8k.jpg')
    Image.new('RGB', (3840,2160), '#1a000d').save('assets/wallpapers/obsidianforge-8k.jpg')

# 4 KDE Themes
def forge_themes():
    themes = ['CyberNexus', 'VoidEmperor', 'QuantumBlade', 'ObsidianForge']
    for t in themes:
        os.makedirs(f'assets/themes/{t}/contents/colors', exist_ok=True)
        with open(f'assets/themes/{t}/metadata.desktop', 'w') as f:
            f.write('[Desktop Entry]\nName={}\nComment=Bucephalus {} Theme\nX-KDE-PluginInfo-Name={}\n'.format(t, t, t))
        with open(f'assets/themes/{t}/contents/colors/{t}.colors', 'w') as f:
            f.write("[Colors:Window]\nBackground=#0D0208\nForeground=#00D4FF\n")

forge_svgs()
forge_wallpapers()
forge_themes()
print("All SVGs, 4 wallpapers & 4 themes freshly forged")
"""

with open('assets/generate_graphics.py', 'w') as f:
    f.write(generate_graphics_script_content)

# !python assets/generate_graphics.py

# STEP 3 – live-build structure + all custom files
# !lb config --mode debian --distribution sid --architecture amd64 --archive-areas "main contrib non-free non-free-firmware" --bootappend-live "boot=live components persistence"

# !mkdir -p config/{package-lists,hooks/live,includes.chroot/usr/{bin,sbin},includes.chroot/usr/share/{plasma/desktoptheme,wallpapers,sounds},includes.binary/usr/share/plymouth/themes}

# Core packages (full pentest + AI + quantum)
bucephalus_core_packages = """linux-image-amd64
kali-linux-large
parrot-tools-full
metasploit-framework
burp-suite
ollama
open-webui
pentestgpt
xbow-ai
hackgpt-enterprise
garak
qiskit
qiskit-aer-gpu
cirq
pennylane
pytket
thunderbird
"""
with open('config/package-lists/bucephalus-core.list.chroot', 'w') as f:
    f.write(bucephalus_core_packages)

# Quantum Gate (auto hardware detection)
quantum_gate_script = """#!/bin/bash
echo \"BUCEPHALUS QUANTUM GATE ACTIVATED\"
if nvidia-smi > /dev/null 2>&1; then
    echo \"GPU DETECTED – 512+ qubit simulation unlocked\"
    export QISKIT_BACKEND=aer_simulator_gpu
elif lscpu | grep -q avx512; then
    echo \"AVX-512 CPU – 312 qubit statevector enabled\"
    export QISKIT_BACKEND=aer_simulator_statevector
else
    echo \"Fallback to 100-qubit QASM simulator\"
    export QISKIT_BACKEND=qasm_simulator
fi
exec python3 \"$@\"
"""
with open('config/includes.chroot/usr/bin/quantum-gate', 'w') as f:
    f.write(quantum_gate_script)
# !chmod +x config/includes.chroot/usr/bin/quantum-gate

# Bucephalus-Mail (encrypted offline client)
buch_mail_script = """#!/bin/bash
exec thunderbird -P \"Bucephalus\" --no-remote
"""
with open('config/includes.chroot/usr/bin/bucephalus-mail', 'w') as f:
    f.write(buch_mail_script)
# !chmod +x config/includes.chroot/usr/bin/bucephalus-mail

# First boot – apply CyberNexus + warm AI
first_boot_script = """#!/bin/bash
cp -r /usr/share/plasma/desktoptheme/CyberNexus /home/live/.local/share/plasma/desktoptheme/ 2>/dev/null || true
echo \"BUCEPHALUS OS – CONQUER THE DIGITAL EMPIRE\" > /etc/motd
ollama serve & sleep 15 && ollama pull llama3.2 &
"""
with open('config/hooks/live/9999-bucephalus.chroot', 'w') as f:
    f.write(first_boot_script)
# !chmod +x config/hooks/live/9999-bucephalus.chroot

# Copy all freshly forged assets into the ISO
# !cp -r assets/bucephalus-* config/includes.chroot/usr/share/ 2>/dev/null || true
# !cp -r assets/wallpapers/* config/includes.chroot/usr/share/wallpapers/ 2>/dev/null || true
# !cp -r assets/themes/* config/includes.chroot/usr/share/plasma/desktoptheme/ 2>/dev/null || true

# STEP 4 – BUILD THE FINAL ISO
# !sudo lb clean --all
# !sudo lb build 2>&1 | tee build.log

# STEP 5 – Save & push
# !mv live-image-amd64.hybrid.iso "/content/drive/MyDrive/Bucephalus-2025.1-Final.iso" 2>/dev/null || echo "ISO built as live-image-amd64.hybrid.iso"

# !git add .
# !git commit -m "Bucephalus 2025.1 Final – Self-forged graphics + full ISO $(date +%F)" || echo "Nothing to commit"
# !git push origin main

# Safely get the size of the ISO or report "Ready"
try:
    size_result = subprocess.run(
        ['du', '-h', 'live-image-amd64.hybrid.iso'],
        capture_output=True,
        text=True,
        check=False # Do not raise an exception for non-zero exit codes
    )
    if size_result.returncode == 0:
        iso_size = size_result.stdout.split()[0] # Get only the size string
    else:
        iso_size = "Ready"
except FileNotFoundError:
    iso_size = "Ready"

print("\nBUCEPHALUS OS 2025.1 SUCCESSFULLY FORGED")
print("ISO location: /content/drive/MyDrive/Bucephalus-2025.1-Final.iso")
print(f"Size: {iso_size}")
print("Your empire is complete. Boot it. Conquer.")
# Out:
# Streaming output truncated to the last 5000 lines.
#  create mode 100644 chroot/usr/share/doc/bsdutils/copyright
#  create mode 100644 chroot/usr/share/doc/coreutils/AUTHORS
#  create mode 100644 chroot/usr/share/doc/coreutils/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/coreutils/README.Debian
#  create mode 100644 chroot/usr/share/doc/coreutils/README.gz
#  create mode 100644 chroot/usr/share/doc/coreutils/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/coreutils/TODO.gz
#  create mode 100644 chroot/usr/share/doc/coreutils/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/coreutils/changelog.gz
#  create mode 100644 chroot/usr/share/doc/coreutils/copyright
#  create mode 100644 chroot/usr/share/doc/cpio/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/cpio/README.gz
#  create mode 100644 chroot/usr/share/doc/cpio/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/cpio/changelog.gz
#  create mode 100644 chroot/usr/share/doc/cpio/copyright
#  create mode 100644 chroot/usr/share/doc/cron-daemon-common/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/cron-daemon-common/changelog.gz
#  create mode 100644 chroot/usr/share/doc/cron-daemon-common/copyright
#  create mode 100644 chroot/usr/share/doc/cron/FEATURES
#  create mode 100644 chroot/usr/share/doc/cron/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/cron/README
#  create mode 100644 chroot/usr/share/doc/cron/README.Debian
#  create mode 100644 chroot/usr/share/doc/cron/README.anacron
#  create mode 100644 chroot/usr/share/doc/cron/THANKS
#  create mode 100644 chroot/usr/share/doc/cron/TODO.Debian
#  create mode 100644 chroot/usr/share/doc/cron/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/cron/changelog.gz
#  create mode 100644 chroot/usr/share/doc/cron/copyright
#  create mode 100644 chroot/usr/share/doc/cron/examples/cron-stats.pl
#  create mode 100644 chroot/usr/share/doc/cron/examples/cron-tasks-review.sh
#  create mode 100644 chroot/usr/share/doc/cron/examples/crontab2english.pl
#  create mode 100644 chroot/usr/share/doc/dash/README.Debian.diet
#  create mode 100644 chroot/usr/share/doc/dash/README.source
#  create mode 100644 chroot/usr/share/doc/dash/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/dash/changelog.gz
#  create mode 100644 chroot/usr/share/doc/dash/copyright
#  create mode 120000 chroot/usr/share/doc/debconf-i18n
#  create mode 100644 chroot/usr/share/doc/debconf/README.Debian
#  create mode 100644 chroot/usr/share/doc/debconf/changelog.gz
#  create mode 100644 chroot/usr/share/doc/debconf/copyright
#  create mode 100644 chroot/usr/share/doc/debian-archive-keyring/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/debian-archive-keyring/README
#  create mode 100644 chroot/usr/share/doc/debian-archive-keyring/changelog.gz
#  create mode 100644 chroot/usr/share/doc/debian-archive-keyring/copyright
#  create mode 100644 chroot/usr/share/doc/debianutils/README.shells
#  create mode 100644 chroot/usr/share/doc/debianutils/changelog.gz
#  create mode 100644 chroot/usr/share/doc/debianutils/copyright
#  create mode 100644 chroot/usr/share/doc/dhcpcd-base/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/dhcpcd-base/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/dhcpcd-base/copyright
#  create mode 100644 chroot/usr/share/doc/dhcpcd-base/examples/90-IPv6_debug_hook
#  create mode 100644 chroot/usr/share/doc/dhcpcd-base/examples/DHCPv6-PD_dhcpcd.conf
#  create mode 100644 chroot/usr/share/doc/diffutils/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/diffutils/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/diffutils/changelog.gz
#  create mode 100644 chroot/usr/share/doc/diffutils/copyright
#  create mode 100644 chroot/usr/share/doc/dmidecode/AUTHORS
#  create mode 100644 chroot/usr/share/doc/dmidecode/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/dmidecode/README.gz
#  create mode 100644 chroot/usr/share/doc/dmidecode/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/dmidecode/copyright
#  create mode 100644 chroot/usr/share/doc/dpkg/AUTHORS
#  create mode 100644 chroot/usr/share/doc/dpkg/README.api
#  create mode 100644 chroot/usr/share/doc/dpkg/README.bug-usertags.gz
#  create mode 100644 chroot/usr/share/doc/dpkg/README.feature-removal-schedule.gz
#  create mode 100644 chroot/usr/share/doc/dpkg/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/dpkg/changelog.gz
#  create mode 100644 chroot/usr/share/doc/dpkg/copyright
#  create mode 100644 chroot/usr/share/doc/e2fsprogs/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/e2fsprogs/README
#  create mode 100644 chroot/usr/share/doc/e2fsprogs/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/e2fsprogs/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/e2fsprogs/copyright
#  create mode 100644 chroot/usr/share/doc/fdisk/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/fdisk/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/fdisk/changelog.gz
#  create mode 100644 chroot/usr/share/doc/fdisk/copyright
#  create mode 100644 chroot/usr/share/doc/findutils/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/findutils/README.gz
#  create mode 100644 chroot/usr/share/doc/findutils/TODO
#  create mode 100644 chroot/usr/share/doc/findutils/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/findutils/changelog.gz
#  create mode 100644 chroot/usr/share/doc/findutils/copyright
#  create mode 100644 chroot/usr/share/doc/gcc-15-base/README.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/gcc-15-base/TODO.Debian
#  create mode 100644 chroot/usr/share/doc/gcc-15-base/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/gcc-15-base/copyright
#  create mode 100644 chroot/usr/share/doc/grep/AUTHORS
#  create mode 100644 chroot/usr/share/doc/grep/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/grep/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/grep/README
#  create mode 100644 chroot/usr/share/doc/grep/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/grep/TODO.gz
#  create mode 100644 chroot/usr/share/doc/grep/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/grep/changelog.gz
#  create mode 100644 chroot/usr/share/doc/grep/copyright
#  create mode 100644 chroot/usr/share/doc/gzip/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/gzip/README.gz
#  create mode 100644 chroot/usr/share/doc/gzip/TODO
#  create mode 100644 chroot/usr/share/doc/gzip/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/gzip/changelog.gz
#  create mode 100644 chroot/usr/share/doc/gzip/copyright
#  create mode 100644 chroot/usr/share/doc/hostname/changelog.gz
#  create mode 100644 chroot/usr/share/doc/hostname/copyright
#  create mode 100644 chroot/usr/share/doc/ifupdown/changelog.gz
#  create mode 100644 chroot/usr/share/doc/ifupdown/contrib/ensureifup
#  create mode 100644 chroot/usr/share/doc/ifupdown/contrib/ifstate
#  create mode 100644 chroot/usr/share/doc/ifupdown/contrib/ifstate-check
#  create mode 100644 chroot/usr/share/doc/ifupdown/copyright
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/bridge
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/check-mac-address.sh
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/generate-interfaces.pl
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/get-mac-address.sh
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/network-interfaces
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/pattern-matching
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/pcmcia-compat.sh
#  create mode 100644 chroot/usr/share/doc/ifupdown/examples/ping-places.sh
#  create mode 100644 chroot/usr/share/doc/init-system-helpers/README.invoke-rc.d.gz
#  create mode 100644 chroot/usr/share/doc/init-system-helpers/README.policy-rc.d.gz
#  create mode 100644 chroot/usr/share/doc/init-system-helpers/changelog.gz
#  create mode 100644 chroot/usr/share/doc/init-system-helpers/copyright
#  create mode 100644 chroot/usr/share/doc/init/changelog.gz
#  create mode 100644 chroot/usr/share/doc/init/copyright
#  create mode 100644 chroot/usr/share/doc/iproute2/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/iproute2/README.Debian
#  create mode 100644 chroot/usr/share/doc/iproute2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/iproute2/copyright
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/README
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/bpf_graft.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/bpf_map_in_map.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/bpf_shared.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/legacy/bpf_cyclic.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/legacy/bpf_graft.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/legacy/bpf_map_in_map.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/legacy/bpf_shared.c
#  create mode 100644 chroot/usr/share/doc/iproute2/examples/bpf/legacy/bpf_tailcall.c
#  create mode 100644 chroot/usr/share/doc/iputils-ping/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/iputils-ping/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/iputils-ping/changelog.gz
#  create mode 100644 chroot/usr/share/doc/iputils-ping/copyright
#  create mode 120000 chroot/usr/share/doc/kmod
#  create mode 100644 chroot/usr/share/doc/less/LESSOPEN
#  create mode 100644 chroot/usr/share/doc/less/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/less/README.Debian
#  create mode 100644 chroot/usr/share/doc/less/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/less/copyright
#  create mode 100644 chroot/usr/share/doc/libacl1/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libacl1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libacl1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libacl1/copyright
#  create mode 100644 chroot/usr/share/doc/libapt-pkg7.0/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libapt-pkg7.0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libapt-pkg7.0/copyright
#  create mode 100644 chroot/usr/share/doc/libattr1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libattr1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libattr1/copyright
#  create mode 100644 chroot/usr/share/doc/libaudit-common/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libaudit-common/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libaudit-common/copyright
#  create mode 100644 chroot/usr/share/doc/libaudit1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libaudit1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libaudit1/copyright
#  create mode 100644 chroot/usr/share/doc/libblkid1/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libblkid1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libblkid1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libblkid1/copyright
#  create mode 100644 chroot/usr/share/doc/libbpf1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libbpf1/copyright
#  create mode 100644 chroot/usr/share/doc/libbsd0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libbsd0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libbsd0/copyright
#  create mode 100644 chroot/usr/share/doc/libbz2-1.0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libbz2-1.0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libbz2-1.0/copyright
#  create mode 100644 chroot/usr/share/doc/libc-bin/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libc-bin/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libc-bin/copyright
#  create mode 100644 chroot/usr/share/doc/libc6/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libc6/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/libc6/README.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libc6/README.hesiod.gz
#  create mode 100644 chroot/usr/share/doc/libc6/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libc6/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libc6/copyright
#  create mode 100644 chroot/usr/share/doc/libcap-ng0/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libcap-ng0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libcap-ng0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libcap-ng0/copyright
#  create mode 100644 chroot/usr/share/doc/libcap2-bin/README.Debian
#  create mode 100644 chroot/usr/share/doc/libcap2-bin/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libcap2-bin/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libcap2-bin/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libcap2-bin/copyright
#  create mode 100644 chroot/usr/share/doc/libcap2/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libcap2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libcap2/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libcap2/copyright
#  create mode 100644 chroot/usr/share/doc/libcom-err2/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libcom-err2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libcom-err2/copyright
#  create mode 100644 chroot/usr/share/doc/libcrypt1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libcrypt1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libcrypt1/copyright
#  create mode 100644 chroot/usr/share/doc/libdb5.3t64/build_signature_amd64.txt
#  create mode 100644 chroot/usr/share/doc/libdb5.3t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libdb5.3t64/copyright
#  create mode 100644 chroot/usr/share/doc/libdebconfclient0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libdebconfclient0/copyright
#  create mode 100644 chroot/usr/share/doc/libedit2/TODO.Debian
#  create mode 100644 chroot/usr/share/doc/libedit2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libedit2/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libedit2/copyright
#  create mode 100644 chroot/usr/share/doc/libelf1t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libelf1t64/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libelf1t64/copyright
#  create mode 100644 chroot/usr/share/doc/libext2fs2t64/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libext2fs2t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libext2fs2t64/copyright
#  create mode 100644 chroot/usr/share/doc/libfdisk1/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libfdisk1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libfdisk1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libfdisk1/copyright
#  create mode 120000 chroot/usr/share/doc/libgcc-s1
#  create mode 100644 chroot/usr/share/doc/libgmp10/README.Debian
#  create mode 100644 chroot/usr/share/doc/libgmp10/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libgmp10/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libgmp10/copyright
#  create mode 100644 chroot/usr/share/doc/libgssapi-krb5-2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libgssapi-krb5-2/copyright
#  create mode 100644 chroot/usr/share/doc/libhogweed6t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libhogweed6t64/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libhogweed6t64/copyright
#  create mode 100644 chroot/usr/share/doc/libidn2-0/AUTHORS
#  create mode 100644 chroot/usr/share/doc/libidn2-0/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/libidn2-0/README.md.gz
#  create mode 100644 chroot/usr/share/doc/libidn2-0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libidn2-0/copyright
#  create mode 100644 chroot/usr/share/doc/libjansson4/README.rst
#  create mode 100644 chroot/usr/share/doc/libjansson4/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libjansson4/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libjansson4/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libjansson4/copyright
#  create mode 100644 chroot/usr/share/doc/libjansson4/examples/json_process.c
#  create mode 100644 chroot/usr/share/doc/libk5crypto3/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libk5crypto3/copyright
#  create mode 100644 chroot/usr/share/doc/libkeyutils1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libkeyutils1/copyright
#  create mode 100644 chroot/usr/share/doc/libkmod2/README.md
#  create mode 100644 chroot/usr/share/doc/libkmod2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libkmod2/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libkmod2/copyright
#  create mode 100644 chroot/usr/share/doc/libkrb5-3/README.Debian
#  create mode 100644 chroot/usr/share/doc/libkrb5-3/README.gz
#  create mode 100644 chroot/usr/share/doc/libkrb5-3/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libkrb5-3/copyright
#  create mode 100644 chroot/usr/share/doc/libkrb5support0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libkrb5support0/copyright
#  create mode 100644 chroot/usr/share/doc/liblocale-gettext-perl/README.Debian
#  create mode 100644 chroot/usr/share/doc/liblocale-gettext-perl/README.gz
#  create mode 100644 chroot/usr/share/doc/liblocale-gettext-perl/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/liblocale-gettext-perl/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/liblocale-gettext-perl/copyright
#  create mode 100644 chroot/usr/share/doc/liblz4-1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/liblz4-1/copyright
#  create mode 100644 chroot/usr/share/doc/liblzma5/AUTHORS
#  create mode 100644 chroot/usr/share/doc/liblzma5/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/liblzma5/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/liblzma5/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/liblzma5/changelog.gz
#  create mode 100644 chroot/usr/share/doc/liblzma5/copyright
#  create mode 100644 chroot/usr/share/doc/libmd0/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libmd0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libmd0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libmd0/copyright
#  create mode 100644 chroot/usr/share/doc/libmnl0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libmnl0/copyright
#  create mode 100644 chroot/usr/share/doc/libmount1/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libmount1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libmount1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libmount1/copyright
#  create mode 120000 chroot/usr/share/doc/libncursesw6
#  create mode 100644 chroot/usr/share/doc/libnettle8t64/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/libnettle8t64/README
#  create mode 100644 chroot/usr/share/doc/libnettle8t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libnettle8t64/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libnettle8t64/copyright
#  create mode 100644 chroot/usr/share/doc/libnewt0.52/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libnewt0.52/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libnewt0.52/copyright
#  create mode 100644 chroot/usr/share/doc/libnftables1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libnftables1/copyright
#  create mode 100644 chroot/usr/share/doc/libnftnl11/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libnftnl11/copyright
#  create mode 100644 chroot/usr/share/doc/libpam-modules-bin/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpam-modules-bin/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libpam-modules-bin/copyright
#  create mode 100644 chroot/usr/share/doc/libpam-modules/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpam-modules/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpam-modules/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libpam-modules/copyright
#  create mode 100644 chroot/usr/share/doc/libpam-modules/examples/upperLOWER.c
#  create mode 100644 chroot/usr/share/doc/libpam-runtime/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpam-runtime/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libpam-runtime/copyright
#  create mode 100644 chroot/usr/share/doc/libpam0g/Debian-PAM-MiniPolicy.gz
#  create mode 100644 chroot/usr/share/doc/libpam0g/README
#  create mode 100644 chroot/usr/share/doc/libpam0g/README.Debian
#  create mode 100644 chroot/usr/share/doc/libpam0g/TODO.Debian
#  create mode 100644 chroot/usr/share/doc/libpam0g/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpam0g/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libpam0g/copyright
#  create mode 100644 chroot/usr/share/doc/libpcre2-8-0/README.Debian
#  create mode 100644 chroot/usr/share/doc/libpcre2-8-0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpcre2-8-0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libpcre2-8-0/copyright
#  create mode 100644 chroot/usr/share/doc/libpopt0/README
#  create mode 100644 chroot/usr/share/doc/libpopt0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libpopt0/copyright
#  create mode 100644 chroot/usr/share/doc/libproc2-0/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libproc2-0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libproc2-0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libproc2-0/copyright
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/README.Debian
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/USAGE
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/copyright
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/examples/Inputrc
#  create mode 100644 chroot/usr/share/doc/libreadline8t64/inputrc.arrows
#  create mode 100644 chroot/usr/share/doc/libseccomp2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libseccomp2/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libseccomp2/copyright
#  create mode 100644 chroot/usr/share/doc/libselinux1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libselinux1/copyright
#  create mode 100644 chroot/usr/share/doc/libsemanage-common/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsemanage-common/copyright
#  create mode 100644 chroot/usr/share/doc/libsemanage2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsemanage2/copyright
#  create mode 100644 chroot/usr/share/doc/libsepol2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsepol2/copyright
#  create mode 100644 chroot/usr/share/doc/libslang2/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/libslang2/README
#  create mode 100644 chroot/usr/share/doc/libslang2/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libslang2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libslang2/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libslang2/copyright
#  create mode 100644 chroot/usr/share/doc/libslang2/slang.txt.gz
#  create mode 100644 chroot/usr/share/doc/libslang2/slangfun.txt.gz
#  create mode 100644 chroot/usr/share/doc/libsmartcols1/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsmartcols1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsmartcols1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libsmartcols1/copyright
#  create mode 100644 chroot/usr/share/doc/libss2/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libss2/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libss2/copyright
#  create mode 100644 chroot/usr/share/doc/libssl3t64/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libssl3t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libssl3t64/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libssl3t64/copyright
#  create mode 120000 chroot/usr/share/doc/libstdc++6
#  create mode 100644 chroot/usr/share/doc/libsystemd-shared/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsystemd-shared/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsystemd-shared/copyright
#  create mode 100644 chroot/usr/share/doc/libsystemd0/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsystemd0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libsystemd0/copyright
#  create mode 100644 chroot/usr/share/doc/libtext-charwidth-perl/README
#  create mode 100644 chroot/usr/share/doc/libtext-charwidth-perl/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/libtext-charwidth-perl/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtext-charwidth-perl/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libtext-charwidth-perl/copyright
#  create mode 100644 chroot/usr/share/doc/libtext-iconv-perl/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtext-iconv-perl/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libtext-iconv-perl/copyright
#  create mode 100644 chroot/usr/share/doc/libtext-wrapi18n-perl/README
#  create mode 100644 chroot/usr/share/doc/libtext-wrapi18n-perl/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtext-wrapi18n-perl/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libtext-wrapi18n-perl/copyright
#  create mode 100644 chroot/usr/share/doc/libtinfo6/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtinfo6/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libtinfo6/copyright
#  create mode 100644 chroot/usr/share/doc/libtirpc-common/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtirpc-common/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtirpc-common/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libtirpc-common/copyright
#  create mode 100644 chroot/usr/share/doc/libtirpc3t64/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtirpc3t64/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libtirpc3t64/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libtirpc3t64/copyright
#  create mode 100644 chroot/usr/share/doc/libudev1/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libudev1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libudev1/copyright
#  create mode 100644 chroot/usr/share/doc/libunistring5/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libunistring5/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libunistring5/copyright
#  create mode 100644 chroot/usr/share/doc/libuuid1/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libuuid1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libuuid1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libuuid1/copyright
#  create mode 100644 chroot/usr/share/doc/libxtables12/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libxtables12/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libxtables12/copyright
#  create mode 100644 chroot/usr/share/doc/libxxhash0/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libxxhash0/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libxxhash0/copyright
#  create mode 100644 chroot/usr/share/doc/libzstd1/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/libzstd1/changelog.gz
#  create mode 100644 chroot/usr/share/doc/libzstd1/copyright
#  create mode 100644 chroot/usr/share/doc/linux-sysctl-defaults/changelog.gz
#  create mode 100644 chroot/usr/share/doc/linux-sysctl-defaults/copyright
#  create mode 100644 chroot/usr/share/doc/login.defs/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/login.defs/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/login.defs/changelog.gz
#  create mode 100644 chroot/usr/share/doc/login.defs/copyright
#  create mode 100644 chroot/usr/share/doc/login/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/login/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/login/changelog.gz
#  create mode 100644 chroot/usr/share/doc/login/copyright
#  create mode 100644 chroot/usr/share/doc/logrotate/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/logrotate/changelog.gz
#  create mode 100644 chroot/usr/share/doc/logrotate/copyright
#  create mode 100644 chroot/usr/share/doc/logsave/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/logsave/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/logsave/copyright
#  create mode 100644 chroot/usr/share/doc/mawk/ACKNOWLEDGMENT
#  create mode 100644 chroot/usr/share/doc/mawk/README
#  create mode 100644 chroot/usr/share/doc/mawk/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/mawk/changelog.gz
#  create mode 100644 chroot/usr/share/doc/mawk/copyright
#  create mode 100755 chroot/usr/share/doc/mawk/examples/ct_length.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/decl.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/deps.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/eatc.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/gdecl.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/hcal
#  create mode 100755 chroot/usr/share/doc/mawk/examples/hical
#  create mode 100755 chroot/usr/share/doc/mawk/examples/nocomment.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/primes.awk
#  create mode 100755 chroot/usr/share/doc/mawk/examples/qsort.awk
#  create mode 100644 chroot/usr/share/doc/mount/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/mount/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/mount/changelog.gz
#  create mode 100644 chroot/usr/share/doc/mount/copyright
#  create mode 100644 chroot/usr/share/doc/mount/examples/filesystems
#  create mode 100644 chroot/usr/share/doc/mount/examples/fstab
#  create mode 100644 chroot/usr/share/doc/mount/examples/mount.fstab
#  create mode 100644 chroot/usr/share/doc/mount/mount.txt
#  create mode 100644 chroot/usr/share/doc/nano/AUTHORS
#  create mode 100644 chroot/usr/share/doc/nano/IMPROVEMENTS.gz
#  create mode 100644 chroot/usr/share/doc/nano/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/nano/README.gz
#  create mode 100644 chroot/usr/share/doc/nano/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/nano/TODO
#  create mode 100644 chroot/usr/share/doc/nano/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/nano/changelog.gz
#  create mode 100644 chroot/usr/share/doc/nano/copyright
#  create mode 100644 chroot/usr/share/doc/nano/examples/sample.nanorc
#  create mode 100644 chroot/usr/share/doc/nano/faq.html
#  create mode 100644 chroot/usr/share/doc/nano/nano.html
#  create mode 100644 chroot/usr/share/doc/ncurses-base/FAQ
#  create mode 100644 chroot/usr/share/doc/ncurses-base/TODO.Debian
#  create mode 100644 chroot/usr/share/doc/ncurses-base/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/ncurses-base/changelog.gz
#  create mode 100644 chroot/usr/share/doc/ncurses-base/copyright
#  create mode 100644 chroot/usr/share/doc/ncurses-bin/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/ncurses-bin/changelog.gz
#  create mode 100644 chroot/usr/share/doc/ncurses-bin/copyright
#  create mode 100644 chroot/usr/share/doc/netbase/changelog.gz
#  create mode 100644 chroot/usr/share/doc/netbase/copyright
#  create mode 100644 chroot/usr/share/doc/nftables/README.Debian
#  create mode 100644 chroot/usr/share/doc/nftables/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/nftables/copyright
#  create mode 100644 chroot/usr/share/doc/nftables/examples/README
#  create mode 100644 chroot/usr/share/doc/nftables/examples/all-in-one.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/arp-filter.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/bridge-filter.nft
#  create mode 100755 chroot/usr/share/doc/nftables/examples/ct_helpers.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/inet-filter.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/inet-nat.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv4-filter.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv4-mangle.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv4-nat.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv4-raw.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv6-filter.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv6-mangle.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv6-nat.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/ipv6-raw.nft
#  create mode 100755 chroot/usr/share/doc/nftables/examples/load_balancing.nft
#  create mode 100755 chroot/usr/share/doc/nftables/examples/nat.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/netdev-ingress.nft
#  create mode 100755 chroot/usr/share/doc/nftables/examples/overview.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/pf.os
#  create mode 100755 chroot/usr/share/doc/nftables/examples/secmark.nft
#  create mode 100755 chroot/usr/share/doc/nftables/examples/sets_and_maps.nft
#  create mode 100644 chroot/usr/share/doc/nftables/examples/sysvinit/README
#  create mode 100644 chroot/usr/share/doc/nftables/examples/sysvinit/nftables.init
#  create mode 100755 chroot/usr/share/doc/nftables/examples/workstation.nft
#  create mode 100644 chroot/usr/share/doc/openssl-provider-legacy/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/openssl-provider-legacy/changelog.gz
#  create mode 100644 chroot/usr/share/doc/openssl-provider-legacy/copyright
#  create mode 100644 chroot/usr/share/doc/passwd/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/passwd/README.Debian
#  create mode 100644 chroot/usr/share/doc/passwd/TODO.Debian
#  create mode 100644 chroot/usr/share/doc/passwd/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/passwd/changelog.gz
#  create mode 100644 chroot/usr/share/doc/passwd/copyright
#  create mode 100755 chroot/usr/share/doc/passwd/examples/passwd.expire.cron
#  create mode 100644 chroot/usr/share/doc/perl-base/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/perl-base/changelog.gz
#  create mode 100644 chroot/usr/share/doc/perl-base/copyright
#  create mode 100644 chroot/usr/share/doc/perl/AUTHORS.gz
#  create mode 100644 chroot/usr/share/doc/perl/Documentation
#  create mode 100644 chroot/usr/share/doc/procps/FAQ.gz
#  create mode 100644 chroot/usr/share/doc/procps/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/procps/README.Debian
#  create mode 100644 chroot/usr/share/doc/procps/bugs.md
#  create mode 100644 chroot/usr/share/doc/procps/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/procps/changelog.gz
#  create mode 100644 chroot/usr/share/doc/procps/copyright
#  create mode 100644 chroot/usr/share/doc/readline-common/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/readline-common/changelog.gz
#  create mode 100644 chroot/usr/share/doc/readline-common/copyright
#  create mode 100644 chroot/usr/share/doc/readline-common/inputrc.arrows
#  create mode 100644 chroot/usr/share/doc/sed/AUTHORS
#  create mode 100644 chroot/usr/share/doc/sed/BUGS.gz
#  create mode 100644 chroot/usr/share/doc/sed/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/sed/README
#  create mode 100644 chroot/usr/share/doc/sed/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/sed/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/sed/changelog.gz
#  create mode 100644 chroot/usr/share/doc/sed/copyright
#  create mode 100644 chroot/usr/share/doc/sed/examples/dc.sed
#  create mode 100644 chroot/usr/share/doc/sed/sedfaq.txt.gz
#  create mode 100644 chroot/usr/share/doc/sensible-utils/changelog.gz
#  create mode 100644 chroot/usr/share/doc/sensible-utils/copyright
#  create mode 100644 chroot/usr/share/doc/sqv/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/sqv/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/sqv/copyright
#  create mode 100644 chroot/usr/share/doc/systemd-sysv/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/systemd-sysv/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/systemd-sysv/copyright
#  create mode 100644 chroot/usr/share/doc/systemd/ENVIRONMENT.md.gz
#  create mode 100644 chroot/usr/share/doc/systemd/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/systemd/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/systemd/README.Debian.gz
#  create mode 100644 chroot/usr/share/doc/systemd/README.gz
#  create mode 100644 chroot/usr/share/doc/systemd/README.logs
#  create mode 100644 chroot/usr/share/doc/systemd/TRANSIENT-SETTINGS.md.gz
#  create mode 100644 chroot/usr/share/doc/systemd/UIDS-GIDS.md.gz
#  create mode 100644 chroot/usr/share/doc/systemd/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/systemd/copyright
#  create mode 100644 chroot/usr/share/doc/sysvinit-utils/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/sysvinit-utils/copyright
#  create mode 100644 chroot/usr/share/doc/tar/AUTHORS
#  create mode 100644 chroot/usr/share/doc/tar/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/tar/README.Debian
#  create mode 100644 chroot/usr/share/doc/tar/THANKS.gz
#  create mode 100644 chroot/usr/share/doc/tar/changelog.1.gz
#  create mode 100644 chroot/usr/share/doc/tar/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/tar/changelog.gz
#  create mode 100644 chroot/usr/share/doc/tar/copyright
#  create mode 100644 chroot/usr/share/doc/tzdata/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/tzdata/README.Debian
#  create mode 100644 chroot/usr/share/doc/tzdata/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/tzdata/changelog.gz
#  create mode 100644 chroot/usr/share/doc/tzdata/copyright
#  create mode 100644 chroot/usr/share/doc/udev/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/udev/README.Debian.gz
#  create mode 100644 chroot/usr/share/doc/udev/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/udev/copyright
#  create mode 100644 chroot/usr/share/doc/util-linux/00-about-docs.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/AUTHORS.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/NEWS.Debian.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/PAM-configuration.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/README.Debian
#  create mode 100644 chroot/usr/share/doc/util-linux/blkid.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/cal.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/changelog.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/col.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/copyright
#  create mode 100644 chroot/usr/share/doc/util-linux/deprecated.txt
#  create mode 100755 chroot/usr/share/doc/util-linux/examples/getopt-example.bash
#  create mode 100644 chroot/usr/share/doc/util-linux/getopt.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/getopt_changelog.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-build-sys.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-compilation.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-contribute.txt.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-debug.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-man-page.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-pull-request.txt.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-tests.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/howto-usage-function.txt.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/hwclock.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/modems-with-agetty.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/mount.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/parse-date.txt.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/pg.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/poeigl.txt.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/release-schedule.txt
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.13-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.14-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.15-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.16-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.17-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.18-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.19-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.20-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.21-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.22-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.23-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.24-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.25-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.26-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.27-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.28-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.29-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.30-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.31-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.32-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.33-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.34-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.35-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.36-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.37-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.38-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.39-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.40-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.41-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.41.1-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/util-linux/releases/v2.41.2-ReleaseNotes.gz
#  create mode 100644 chroot/usr/share/doc/vim-common/README.Debian
#  create mode 100644 chroot/usr/share/doc/vim-common/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/vim-common/changelog.gz
#  create mode 100644 chroot/usr/share/doc/vim-common/copyright
#  create mode 100644 chroot/usr/share/doc/vim-tiny/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/vim-tiny/changelog.gz
#  create mode 100644 chroot/usr/share/doc/vim-tiny/copyright
#  create mode 100644 chroot/usr/share/doc/whiptail/NEWS.gz
#  create mode 100644 chroot/usr/share/doc/whiptail/README.whiptail
#  create mode 100644 chroot/usr/share/doc/whiptail/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/whiptail/changelog.gz
#  create mode 100644 chroot/usr/share/doc/whiptail/copyright
#  create mode 100644 chroot/usr/share/doc/zlib1g/changelog.Debian.amd64.gz
#  create mode 100644 chroot/usr/share/doc/zlib1g/changelog.Debian.gz
#  create mode 100644 chroot/usr/share/doc/zlib1g/changelog.gz
#  create mode 100644 chroot/usr/share/doc/zlib1g/copyright
#  create mode 100644 chroot/usr/share/dpkg/abitable
#  create mode 100644 chroot/usr/share/dpkg/cputable
#  create mode 100644 chroot/usr/share/dpkg/ostable
#  create mode 100644 chroot/usr/share/dpkg/sh/dpkg-error.sh
#  create mode 100644 chroot/usr/share/dpkg/tupletable
#  create mode 100644 chroot/usr/share/factory/etc/issue
#  create mode 100644 chroot/usr/share/factory/etc/locale.conf
#  create mode 100644 chroot/usr/share/factory/etc/nsswitch.conf
#  create mode 100644 chroot/usr/share/factory/etc/pam.d/other
#  create mode 100644 chroot/usr/share/factory/etc/pam.d/system-auth
#  create mode 100644 chroot/usr/share/factory/etc/vconsole.conf
#  create mode 100644 chroot/usr/share/fish/completions/sqv.fish
#  create mode 100644 chroot/usr/share/fish/vendor_functions.d/insmod.fish
#  create mode 100644 chroot/usr/share/fish/vendor_functions.d/lsmod.fish
#  create mode 100644 chroot/usr/share/fish/vendor_functions.d/rmmod.fish
#  create mode 100644 chroot/usr/share/gcc/python/libstdcxx/__init__.py
#  create mode 100644 chroot/usr/share/gcc/python/libstdcxx/v6/__init__.py
#  create mode 100644 chroot/usr/share/gcc/python/libstdcxx/v6/printers.py
#  create mode 100644 chroot/usr/share/gcc/python/libstdcxx/v6/xmethods.py
#  create mode 100644 chroot/usr/share/gdb/auto-load/usr/lib/x86_64-linux-gnu/libstdc++.so.6.0.34-gdb.py
#  create mode 100644 chroot/usr/share/icons/hicolor/48x48/apps/gvim.png
#  create mode 100644 chroot/usr/share/icons/hicolor/scalable/apps/gvim.svg
#  create mode 100644 chroot/usr/share/icons/locolor/16x16/apps/gvim.png
#  create mode 100644 chroot/usr/share/icons/locolor/32x32/apps/gvim.png
#  create mode 100644 chroot/usr/share/info/coreutils.info.gz
#  create mode 100644 chroot/usr/share/info/diffutils.info.gz
#  create mode 100644 chroot/usr/share/info/dir
#  create mode 100644 chroot/usr/share/info/find-maint.info.gz
#  create mode 100644 chroot/usr/share/info/find.info.gz
#  create mode 100644 chroot/usr/share/info/grep.info.gz
#  create mode 100644 chroot/usr/share/info/gzip.info.gz
#  create mode 100644 chroot/usr/share/info/nano.info.gz
#  create mode 100644 chroot/usr/share/info/rluserman.info.gz
#  create mode 100644 chroot/usr/share/info/sed.info.gz
#  create mode 100755 chroot/usr/share/initramfs-tools/hooks/kmod
#  create mode 100755 chroot/usr/share/initramfs-tools/hooks/udev
#  create mode 100755 chroot/usr/share/initramfs-tools/scripts/init-bottom/udev
#  create mode 100755 chroot/usr/share/initramfs-tools/scripts/init-top/udev
#  create mode 100644 chroot/usr/share/iproute2/bpf_pinning
#  create mode 100644 chroot/usr/share/iproute2/ematch_map
#  create mode 100644 chroot/usr/share/iproute2/group
#  create mode 100644 chroot/usr/share/iproute2/nl_protos
#  create mode 100644 chroot/usr/share/iproute2/rt_dsfield
#  create mode 100644 chroot/usr/share/iproute2/rt_protos
#  create mode 100644 chroot/usr/share/iproute2/rt_realms
#  create mode 100644 chroot/usr/share/iproute2/rt_scopes
#  create mode 100644 chroot/usr/share/iproute2/rt_tables
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-bookworm-automatic.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-bookworm-automatic.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-bookworm-security-automatic.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-bookworm-security-automatic.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-bookworm-stable.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-bookworm-stable.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-bullseye-automatic.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-bullseye-automatic.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-bullseye-security-automatic.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-bullseye-security-automatic.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-bullseye-stable.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-bullseye-stable.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-keyring.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-keyring.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-removed-keys.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-removed-keys.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-trixie-automatic.gpg
#  create mode 100644 chroot/usr/share/keyrings/debian-archive-trixie-automatic.pgp
#  create mode 120000 chroot/usr/share/keyrings/debian-archive-trixie-security-automatic.gpg
# ...
#  create mode 100644 chroot/var/lib/dpkg/info/libsystemd0:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libsystemd0:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libtext-charwidth-perl:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libtext-charwidth-perl:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libtext-iconv-perl:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libtext-iconv-perl:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libtext-wrapi18n-perl.list
#  create mode 100644 chroot/var/lib/dpkg/info/libtext-wrapi18n-perl.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libtinfo6:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libtinfo6:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libtinfo6:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libtinfo6:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libtinfo6:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc-common.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc-common.list
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc-common.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.preinst
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libtirpc3t64:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libudev1:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libudev1:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libudev1:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libudev1:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libudev1:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libunistring5:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libunistring5:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libunistring5:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libunistring5:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libunistring5:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libuuid1:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libuuid1:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libuuid1:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libuuid1:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libuuid1:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libxtables12:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libxtables12:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libxtables12:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libxtables12:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libxtables12:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libxxhash0:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libxxhash0:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libxxhash0:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libxxhash0:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/libxxhash0:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/libzstd1:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/libzstd1:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/libzstd1:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/libzstd1:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/linux-sysctl-defaults.list
#  create mode 100644 chroot/var/lib/dpkg/info/linux-sysctl-defaults.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/login.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/login.defs.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/login.defs.list
#  create mode 100644 chroot/var/lib/dpkg/info/login.defs.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/login.defs.postinst
#  create mode 100644 chroot/var/lib/dpkg/info/login.list
#  create mode 100644 chroot/var/lib/dpkg/info/login.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/login.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/login.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/login.preinst
#  create mode 100755 chroot/var/lib/dpkg/info/login.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/logrotate.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/logrotate.list
#  create mode 100644 chroot/var/lib/dpkg/info/logrotate.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/logrotate.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/logrotate.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/logrotate.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/logsave.list
#  create mode 100644 chroot/var/lib/dpkg/info/logsave.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/mawk.list
#  create mode 100644 chroot/var/lib/dpkg/info/mawk.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/mawk.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/mawk.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/mount.list
#  create mode 100644 chroot/var/lib/dpkg/info/mount.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/nano.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/nano.list
#  create mode 100644 chroot/var/lib/dpkg/info/nano.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/nano.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/nano.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/ncurses-base.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/ncurses-base.list
#  create mode 100644 chroot/var/lib/dpkg/info/ncurses-base.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/ncurses-bin.list
#  create mode 100644 chroot/var/lib/dpkg/info/ncurses-bin.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/netbase.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/netbase.list
#  create mode 100644 chroot/var/lib/dpkg/info/netbase.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/netbase.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/netbase.postrm
#  create mode 100644 chroot/var/lib/dpkg/info/nftables.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/nftables.list
#  create mode 100644 chroot/var/lib/dpkg/info/nftables.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/nftables.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/nftables.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/nftables.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/openssl-provider-legacy.list
#  create mode 100644 chroot/var/lib/dpkg/info/openssl-provider-legacy.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/passwd.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/passwd.list
#  create mode 100644 chroot/var/lib/dpkg/info/passwd.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/passwd.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/passwd.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/passwd.preinst
#  create mode 100755 chroot/var/lib/dpkg/info/passwd.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/perl-base.list
#  create mode 100644 chroot/var/lib/dpkg/info/perl-base.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/procps.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/procps.list
#  create mode 100644 chroot/var/lib/dpkg/info/procps.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/procps.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/procps.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/procps.preinst
#  create mode 100755 chroot/var/lib/dpkg/info/procps.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/procps.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/readline-common.list
#  create mode 100644 chroot/var/lib/dpkg/info/readline-common.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/readline-common.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/readline-common.postrm
#  create mode 100644 chroot/var/lib/dpkg/info/sed.list
#  create mode 100644 chroot/var/lib/dpkg/info/sed.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/sensible-utils.list
#  create mode 100644 chroot/var/lib/dpkg/info/sensible-utils.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/sqv.list
#  create mode 100644 chroot/var/lib/dpkg/info/sqv.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/systemd-sysv.list
#  create mode 100644 chroot/var/lib/dpkg/info/systemd-sysv.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/systemd-sysv.postinst
#  create mode 100644 chroot/var/lib/dpkg/info/systemd.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/systemd.list
#  create mode 100644 chroot/var/lib/dpkg/info/systemd.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/systemd.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/systemd.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/systemd.preinst
#  create mode 100755 chroot/var/lib/dpkg/info/systemd.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/systemd.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/sysvinit-utils.list
#  create mode 100644 chroot/var/lib/dpkg/info/sysvinit-utils.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/tar.list
#  create mode 100644 chroot/var/lib/dpkg/info/tar.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/tar.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/tar.prerm
#  create mode 100755 chroot/var/lib/dpkg/info/tzdata.config
#  create mode 100644 chroot/var/lib/dpkg/info/tzdata.list
#  create mode 100644 chroot/var/lib/dpkg/info/tzdata.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/tzdata.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/tzdata.postrm
#  create mode 100644 chroot/var/lib/dpkg/info/tzdata.templates
#  create mode 100644 chroot/var/lib/dpkg/info/udev.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/udev.list
#  create mode 100644 chroot/var/lib/dpkg/info/udev.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/udev.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/udev.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/udev.preinst
#  create mode 100755 chroot/var/lib/dpkg/info/udev.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/udev.triggers
#  create mode 100644 chroot/var/lib/dpkg/info/util-linux.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/util-linux.list
#  create mode 100644 chroot/var/lib/dpkg/info/util-linux.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/util-linux.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/util-linux.postrm
#  create mode 100755 chroot/var/lib/dpkg/info/util-linux.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/vim-common.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/vim-common.list
#  create mode 100644 chroot/var/lib/dpkg/info/vim-common.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/vim-common.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/vim-common.postrm
#  create mode 100644 chroot/var/lib/dpkg/info/vim-tiny.conffiles
#  create mode 100644 chroot/var/lib/dpkg/info/vim-tiny.list
#  create mode 100644 chroot/var/lib/dpkg/info/vim-tiny.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/vim-tiny.postinst
#  create mode 100755 chroot/var/lib/dpkg/info/vim-tiny.prerm
#  create mode 100644 chroot/var/lib/dpkg/info/whiptail.list
#  create mode 100644 chroot/var/lib/dpkg/info/whiptail.md5sums
#  create mode 100755 chroot/var/lib/dpkg/info/whiptail.preinst
#  create mode 100644 chroot/var/lib/dpkg/info/zlib1g:amd64.list
#  create mode 100644 chroot/var/lib/dpkg/info/zlib1g:amd64.md5sums
#  create mode 100644 chroot/var/lib/dpkg/info/zlib1g:amd64.shlibs
#  create mode 100644 chroot/var/lib/dpkg/info/zlib1g:amd64.symbols
#  create mode 100644 chroot/var/lib/dpkg/info/zlib1g:amd64.triggers
#  create mode 100644 chroot/var/lib/dpkg/lock
#  create mode 100644 chroot/var/lib/dpkg/lock-frontend
#  create mode 100644 chroot/var/lib/dpkg/statoverride
#  create mode 100644 chroot/var/lib/dpkg/status
#  create mode 100644 chroot/var/lib/dpkg/status-old
#  create mode 100644 chroot/var/lib/dpkg/triggers/File
#  create mode 100644 chroot/var/lib/dpkg/triggers/Lock
#  create mode 100644 chroot/var/lib/dpkg/triggers/Unincorp
#  create mode 100644 chroot/var/lib/dpkg/triggers/ldconfig
#  create mode 100644 chroot/var/lib/dpkg/triggers/libc-upgrade
#  create mode 100644 chroot/var/lib/pam/account
#  create mode 100644 chroot/var/lib/pam/auth
#  create mode 100644 chroot/var/lib/pam/password
#  create mode 100644 chroot/var/lib/pam/seen
#  create mode 100644 chroot/var/lib/pam/session
#  create mode 100644 chroot/var/lib/pam/session-noninteractive
#  create mode 100644 chroot/var/lib/shells.state
#  create mode 100644 chroot/var/lib/systemd/catalog/database
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/apt-daily-upgrade.timer.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/apt-daily.timer.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/cron.service.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/dpkg-db-backup.timer.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/e2scrub_all.timer.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/e2scrub_reap.service.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/fstrim.timer.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/ifupdown-wait-online.service.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/logrotate.timer.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/multi-user.target.wants/cron.service
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/multi-user.target.wants/e2scrub_reap.service
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/multi-user.target.wants/networking.service
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/network-online.target.wants/networking.service
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/networking.service.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/nftables.service.dsh-also
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/apt-daily-upgrade.timer
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/apt-daily.timer
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/dpkg-db-backup.timer
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/e2scrub_all.timer
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/fstrim.timer
#  create mode 100644 chroot/var/lib/systemd/deb-systemd-helper-enabled/timers.target.wants/logrotate.timer
#  create mode 120000 chroot/var/lock
#  create mode 120000 chroot/var/log/README
#  create mode 100644 chroot/var/log/alternatives.log
#  create mode 100644 chroot/var/log/bootstrap.log
#  create mode 100644 chroot/var/log/btmp
#  create mode 100644 chroot/var/log/dpkg.log
#  create mode 100644 chroot/var/log/lastlog
#  create mode 100644 chroot/var/log/wtmp
#  create mode 120000 chroot/var/run
#  create mode 120000 chroot/var/spool/mail
#  create mode 100644 config/binary
#  create mode 100644 config/bootstrap
#  create mode 100644 config/chroot
#  create mode 100644 config/common
#  create mode 100755 config/hooks/live/9999-bucephalus.chroot
#  create mode 100755 config/includes.chroot/usr/bin/bucephalus-mail
#  create mode 100755 config/includes.chroot/usr/bin/quantum-gate
#  create mode 100644 config/package-lists/bucephalus-core.list.chroot
#  create mode 100644 config/source
# fatal: could not read Username for 'https://github.com': No such device or address
#
# BUCEPHALUS OS 2025.1 SUCCESSFULLY FORGED
# ISO location: /content/drive/MyDrive/Bucephalus-2025.1-Final.iso
# Size: Ready
# Your empire is complete. Boot it. Conquer.
